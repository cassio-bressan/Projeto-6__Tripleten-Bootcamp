# %% [markdown]
# # Revisão de código
#
# Olá!
#
# Meu nome é Suelen. Estou feliz em revisar seu projeto hoje!
#
# Quando vejo um erro pela primeira vez, apenas aponto. Deixarei você encontrá-lo e corrigi-lo sozinho. Além disso, ao longo do texto, farei algumas observações sobre melhorias no código e também farei comentários sobre suas percepções sobre o assunto. Mas se você ainda não consegue lidar com essa tarefa, darei uma dica mais precisa na próxima iteração e também alguns exemplos práticos. Estarei aberto a feedbacks e discussões sobre o tema.
#
# Você pode encontrar meus comentários em caixas verdes, amarelas ou vermelhas como estas:
#
#
# <div class="alert alert-block alert-success">
# <b>Comentário: </b> <a class="tocSkip"></a>
#
# Sucesso. Tudo está correto.
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Comentário: </b> <a class="tocSkip"></a>
#
# Observações. Algumas recomendações.
# </div>
#
# <div class="alert alert-block alert-danger">
#
# <b>Comentário: </b> <a class="tocSkip"></a>
#
# O bloco requer algumas correções. O trabalho não pode ser aceito com os comentários vermelhos.
# </div>
#
# Você pode me responder usando isto:
#
# <div class="alert alert-block alert-info">
# <b>Resposta do aluno</b> <a class="tocSkip"></a>
# </div>

# %% [markdown]
# ``- Fiz as modificações que você sugeriu. Quanto ao tratamento da coluna 'year_of_release' eu apenas copiei o código que o tutor sugeriu no discord, mas sim, a intenção é preencher os dados de ano de um jogo A com base nos dados do mesmo jogo A porém para uma plataforma diferente. Copiei o código do tutor pois travei nessa questão e não sabia de que forma poderia ser feita.``
#
# ``- Fiz novamente algumas modificações nos códigos e peço desculpas desde já pois talvez eu tenha alterado algum gráfico que você modificou para conseguir ler. Atualizei o teste de hipóteses e fiz alguns comentários com base nas hipóteses testadas. Também fiz alguns comentários ao longo do projeto para discutir alguns pontos que talvez tenham ficado em dúvida.``

# %% [markdown]
# <div class="alert alert-block alert-danger">
#
# <b>Comentário v1: </b> <a class="tocSkip"></a>
#
#
#
# Parabéns pelo desenvolvimento do projeto, Cássio! 👏🚀
#
# Para prosseguirmos com a revisão, são necessários alguns ajustes no código. Inseri comentários ao longo do projeto para te orientar na resolução.
#
# Estou à disposição para eventuais dúvidas.
#
# Boa sorte!
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
#
# <b>Comentário v2: </b> <a class="tocSkip"></a>
#
# Obrigado pelos ajustes, Cássio!
#
# Revisei o código e incluí um comentário sobre os ajustes na seção de teste de hipóteses. Seu trabalho está de alta qualidade e estamos próximos da aprovação.
#
# PS: A biblioteca do seaborn na tripleten é diferente da versão que você usou para desenvolver o código, então refiz os gráficos para visualizá-los no meu ambiente.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentário: </b> <a class="tocSkip"></a>
#
# Parabéns! O projeto está aprovado.
# </div>

# %% [markdown]
# # PROJETO INTEGRADO

# %% [markdown]
# ## Descrição de dados
# `—Name` (nome)
#
# `—Platform` (plataforma)
#
# `—Year_of_Release` (Ano de lançamento)
#
# `—Genre` (gênero)
#
# `—NA_sales` (vendas norte-americanas em milhões de USD)
#
# `—EU_sales` (vendas na Europa em milhões de USD)
#
# `—JP_sales` (vendas no Japão em milhões de USD)
#
# `—Other_sales` (vendas em outros países em em milhões de USD)
#
# `—Critic_Score` (Pontuação crítica) (máximo de 100)
#
# `—User_Score` (Pontuação do usuário) (máximo de 10)
#
# `—Classificação` (ESRB)

# %%
# IMPORTANDO OS PACOTES.
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
from scipy import stats as st

# %%
# CARREGANDO OS DADOS
df_games = pd.read_csv('/datasets/games.csv')

# %% [markdown]
# <div class="alert alert-block alert-danger">
#
# <b>Comentário: </b> <a class="tocSkip"></a>
#
# Por favor corrija o endereço de leitura do arquivo. Você utilizou o endereço do arquivo local da sua máquina, o que acaba não funcionando na plataforma.
# Eu inseri o endereço correto abaixo para prosseguir a revisão.
# </div>

# %%
# CARREGANDO INFORMAÇÕES DO DATAFRAME.
df_games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             16713 non-null  object
#  1   Platform         16715 non-null  object
#  2   Year_of_Release  16446 non-null  float64
#  3   Genre            16713 non-null  object
#  4   NA_sales         16715 non-null  float64
#  5   EU_sales         16715 non-null  float64
#  6   JP_sales         16715 non-null  float64
#  7   Other_sales      16715 non-null  float64
#  8   Critic_Score     8137 non-null   float64
#  9   User_Score       10014 non-null  object
#  10  Rating           9949 non-null   object
# dtypes: float64(6), object(5)
# memory usage: 1.4+ MB

# %%
# CARREGANDO AMOSTRA DOS DADOS.
df_games.sample(10)
# Out:
#                                                 Name Platform  \
# 4310                   Dynasty Warriors: Strikeforce      PSP
# 10903                                     Wordmaster       DS
# 2894                    Doom 3: Resurrection of Evil       XB
# 8292                            Hanjuku Eiyuu Tai 3D      PS2
# 798                                      Yokai Watch      3DS
# 4861                             Ultimate Spider-Man       XB
# 5529   Samurai Warriors 2: Xtreme Legends (JP sales)      PS2
# 11920                     Tom Clancy's Ghost Recon 2       GC
# 9004                             Fox Sports Golf '99       PS
# 11609                               Song of the Deep      PS4
#
#        Year_of_Release         Genre  NA_sales  EU_sales  JP_sales  \
# 4310            2009.0        Action      0.03      0.02      0.38
# 10903           2008.0      Strategy      0.09      0.00      0.00
# 2894            2005.0       Shooter      0.53      0.15      0.00
# ...

# %% [markdown]
# ``O dataframe possui alguns erros que precisam ser tratados como:``
#
# ``- Padronização de texto, conversão para minúsculos.``
#
# ``- Dados com o tipo errado,conversão de tipo de dados.``
#
# ``- Valores ausentes, remoção de valores faltantes.``
#
# ``- Possíveis valores duplicados, remoção de valores duplicados.``
#
# ``- Strings em colunas que deveriam ser númericas, tratamento de valores.``

# %% [markdown]
# ### TRATAMENTO DO DATAFRAME

# %%
# SUBSTITUINNDO OS NOMES DAS COLUNAS POR MÍNUSCULOS.
def lowercase_columns(df):
    new_columns = [col.lower() for col in df.columns]
    df.columns = new_columns
    return df


df_games = lowercase_columns(df_games)
print(df_games.columns)
# Out:
# Index(['name', 'platform', 'year_of_release', 'genre', 'na_sales', 'eu_sales',
#        'jp_sales', 'other_sales', 'critic_score', 'user_score', 'rating'],
#       dtype='object')

# %%
# SUBSTITUINDO OS DADOS PARA MINÚSCULO
columns_lower = ['name', 'platform', 'genre']
for data in columns_lower:
    df_games[data] = df_games[data].str.lower()

# %%
# CONVERTENDO OS TIPOS DE DADOS DO DATAFRAME
df_games['user_score'] = df_games['user_score'].replace('tbd', np.nan) #Converti os ''tbd'' para NaNs para que seja possível fazer a conversão dos dados da coluna para o tipo correto.
df_games['user_score'] = df_games['user_score'].astype(float)

# %% [markdown]
# ``Substitui os valores 'tbd' da coluna 'user_score' por NaNs para que eu pudesse transformar todos os dados da coluna em float posteriormente.``
# ``Decidi não trabalhar com esses dados pois 'tbd' e 'NaNs' nesse caso são basicamente a mesma coisa, mas posteriormente irei converter NaNs para missing junto com os outros NaNs.``

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Comentário: </b> <a class="tocSkip"></a>
#
# Processamento dos dados foi realizado corretamente. Como sugestão para um processamento mais rápido:
#
#
#     def columns_format(df):
#     """Função para formatar os nomes das colunas"""
#     df.columns = df.columns.str.lower().str.replace(' ', '_').str.strip()
#     return df
#
# </div>

# %% [markdown]
# ### TRATAMENTO ESPECIAL PARA A COLUNA 'year_of_release'

# %%
# PREENCHENDO VALORES FALTANTES COM BASE EM VALORES EXISTENTES DE UM JOGO PARA UMA PLATAFORMA DIFERENTE.
df_games.dropna(subset=['name'], inplace=True) ##Adicionado pela revisora

df_games['year_of_release'] = df_games.groupby(['name','platform'])['year_of_release'].transform(lambda x: x.fillna(x.min()))
df_games['year_of_release'] = df_games.groupby(['name'])['year_of_release'].transform(lambda x: x.fillna(x.min()))
df_games['year_of_release'] = df_games.groupby(['platform'])['year_of_release'].transform(lambda x: x.fillna(x.min()))
df_games['year_of_release'] = df_games['year_of_release'].astype('Int64')

# %% [markdown]
# ``A coluna 'year_of_release' possuia valores faltantes para alguns jogos, porém, alguns dados com jogos do mesmo nome para uma plataforma diferente possuiam o valor de 'year_of_release'. Como eu não sabia como preencher os dados com base no nome e na plataforma que possuiam os mesmos dados de ano de lançamento, dei uma olhada no canal do discord e o tutor havia dado essa idéia de como resolver essa questão especificamente. Em seguida modifiquei os dados da coluna para o tipo correto.``

# %% [markdown]
# <div class="alert alert-block alert-danger">
#
# <b>Comentário: </b> <a class="tocSkip"></a>
#
# O código apresenta erro durante o processamento.
# O erro ocorre porque as transformações aplicadas em `df_games['year_of_release']` resultam em comprimentos de dados diferentes do esperado devido às operações de agrupamento e preenchimento.
#
# Para confirmar: você pretende preencher os valores nulos de `year_of_release` com base nos jogos que possuem valores válidos de `year_of_release`? Por exemplo, se o jogo A tiver um ano de lançamento definido na plataforma X, mas não na plataforma Y, você deseja preencher o valor de `year_of_release` na plataforma Y com base na plataforma X, correto?
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# <b>Comentário: </b> <a class="tocSkip"></a>
#
# Entendi! O erro do código se deve devido à diferença de comprimento dos dados (É como se você tivesse tentando encaixar uma pizza de 30 pedaços dentro de uma caixa de uma mini pizza.). Essa diferença se deve devido a presença de linhas com nomes nulos. Então a função não conseguia fazer o processamento dos dados de forma correta. Eu adicionei uma linha de código com a exclusão dos nomes nulos. Agora funcionou!
# </div>

# %% [markdown]
# ``Obrigado pela linha! Essa questão realmente não soube como construir, mas que bom que estava no caminho certo!!``

# %% [markdown]
# ### TRATAMENTO ESPECIAL PARA A PLATAFORMA 'DS'

# %%
def replace_year(row):
    if row['platform'] == 'ds' and row['year_of_release'] == 1985:
        return 2004
    return row['year_of_release']


df_games['year_of_release'] = df_games.apply(replace_year, axis=1)

# %% [markdown]
# ``A coluna 'year_of_release' para a plataforma ds em alguns casos estava com o ano de 1985 após o tratamento anterior. Porém a plataforma ds foi lançada apenas em 2004, então substitui todos os valores em que coluna 'year_of_release' era 1985 para 2004.``

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Comentário: </b> <a class="tocSkip"></a>
#
# O código acima está correto, mas atente-se ao fato de que há outros anos anteriores a 2024 na análise, conforme célula abaixo
#
# </div>

# %% [markdown]
# ``Estou ciente de que há anos anteriores a 2004 na análise, mas esse tratamento especial para a forma ds foi feito após eu já ter feito toda a análise e após escolher apenas os dados relevantes. Como ao longo do projeto decidi usar apenas dados acima dos anos 2000 e como ds é uma plataforma de extremo sucesso, voltei nessa parte do projeto e dei um tratamento especial para que eu obtivesse análises mais proximas da realidade com o conjunto de dados que decidi trabalhar.``

# %% [markdown]
# ### TRATAMENTO DE VALORES AUSENTES

# %%
# ENCONTRANDO VALORES AUSENTES
df_games.isna().sum()
# Out:
# name                  0
# platform              0
# year_of_release       0
# genre                 0
# na_sales              0
# eu_sales              0
# jp_sales              0
# other_sales           0
# critic_score       8576
# user_score         9123
# rating             6764
# dtype: int64

# %%
# REMOVENDO JOGOS SEM NOME, POIS É IMPOSSÍVEL DESCOBRIR.
df_games.dropna(subset=['name'],inplace=True)

# %%
# REMOVENDO VALORES AUSENTES.
column_to_replace = ['genre','rating']
for col in column_to_replace:
    df_games.fillna({col: 'missing'}, inplace = True)

# %% [markdown]
# ``Decidi substituir os valores ausentes por missing apenas nas colunas do tipo 'Object'. Em relação às colunas 'user_score' e 'critic_score', resolvi manter os dados ausentes pois dessa forma não altero o tipo dos dados e também porque acredito que preencher esses valores irá mais atrapalhar do que ajudar na análise.``

# %%
# VERIFICANDO NOVAMENTE OS VALORES AUSENTES
df_games.isna().sum()
# Out:
# name                  0
# platform              0
# year_of_release       0
# genre                 0
# na_sales              0
# eu_sales              0
# jp_sales              0
# other_sales           0
# critic_score       8576
# user_score         9123
# rating                0
# dtype: int64

# %% [markdown]
# ### TRATAMENTO DE DUPLICADOS

# %%
# VERIFICANDO LINHAS TOTALMENTE DUPLICADAS.
df_games[df_games.duplicated()]
# Out:
# Empty DataFrame
# Columns: [name, platform, year_of_release, genre, na_sales, eu_sales, jp_sales, other_sales, critic_score, user_score, rating]
# Index: []

# %%
# VERIFICANDO DUPLICADOS COM BASE EM COLUNAS ESPECÍFICAS.
df_games[df_games.duplicated(subset=['name', 'platform','year_of_release'])]
# Out:
#                      name platform  year_of_release     genre  na_sales  \
# 4127   sonic the hedgehog      ps3             2006  platform       0.0
# 16230       madden nfl 13      ps3             2012    sports       0.0
#
#        eu_sales  jp_sales  other_sales  critic_score  user_score rating
# 4127       0.48       0.0          0.0          43.0         4.1   E10+
# 16230      0.01       0.0          0.0          83.0         5.5      E

# %%
# REMOVENDO DUPLICADOS COM BASE NAS COLUNAS.
df_games.drop_duplicates(subset=['name','platform','year_of_release'],inplace=True)

# %%
#VERIFICANDO NOVAMENTE DUPLICADOS.
df_games[df_games.duplicated(subset=['name', 'platform', 'year_of_release'])]
# Out:
# Empty DataFrame
# Columns: [name, platform, year_of_release, genre, na_sales, eu_sales, jp_sales, other_sales, critic_score, user_score, rating]
# Index: []

# %% [markdown]
# `` Verifiquei e tratei os duplicados com base em 3 colunas específicas para ter a certeza de que não há um mesmo jogo lançado para a mesma plataforma no mesmo ano.``

# %% [markdown]
# ### CALCULANDO O TOTAL DE VENDAS

# %%
# CRIANDO UMA COLUNA DE VENDAS TOTAIS DE CADA JOGO.
df_games['total_sales'] = df_games['na_sales'] + df_games['eu_sales'] + df_games['jp_sales'] + df_games['other_sales']
df_games.sample(5)
# Out:
#                                                     name platform  \
# 8367                               bladestorm: nightmare      ps4
# 9374                                     life is strange     xone
# 16090                   blazblue: continuum shift extend      psp
# 16514  uchida yasuou mystery: meitantei senken mitsuh...       ds
# 7268                            hasbro family game night       ds
#
#        year_of_release      genre  na_sales  eu_sales  jp_sales  other_sales  \
# 8367              2015     action      0.08      0.04      0.03         0.02
# 9374              2016  adventure      0.09      0.03      0.00         0.01
# 16090             2012   fighting      0.00      0.00      0.01         0.00
# 16514             2009  adventure      0.00      0.00      0.01         0.00
# 7268              2009     puzzle      0.01      0.19      0.00         0.02
#
#        critic_score  user_score   rating  total_sales
# ...

# %%
# VERIFICANDO O NÚMERO DE JOGOS LANÇADOS POR ANO.
games_by_year = df_games.groupby(['year_of_release',])['name'].count().sort_values(ascending=False).reset_index(name='games_number')
games_by_year.head(10)
# Out:
#    year_of_release  games_number
# 0             2008          1441
# 1             2009          1430
# 2             2010          1269
# 3             2007          1202
# 4             2011          1154
# 5             2006          1037
# 6             2005           971
# 7             2002           845
# 8             2004           793
# 9             2003           783

# %%
# Código gerado pela revisora
import matplotlib.pyplot as plt

# Assuming df_games and year_of_release are already defined

# Increase the figure size
plt.figure(figsize=(10, 6))  # Adjust the width and height as needed

# Plot the horizontal bar chart
df_games.year_of_release.value_counts().plot(kind='barh')

# Set labels and title
plt.xlabel('Count')
plt.ylabel('Year of Release')
plt.title('Number of Games Released by Year')

# Show the plot
plt.show()

# %% [markdown]
# ``Movi seu código para essa sessão onde verifico o número de jogos lançados por ano. No meu código eu não fiz uso de gráfico e apenas printei as 10 mais relevantes, há algum problema na forma como fiz? Verifiquei os resultados e são os mesmos.``

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentário: </b> <a class="tocSkip"></a>
#
# Não tem problema nenhum! :)
# </div>

# %%
games_by_year['games_number'].describe()
# Out:
# count      37.000000
# mean      451.648649
# std       456.753776
# min        14.000000
# 25%        36.000000
# 50%       339.000000
# 75%       783.000000
# max      1441.000000
# Name: games_number, dtype: float64

# %% [markdown]
# ``Os dados mostram que de 2002 a 2011 o número de jogos lançados cresceu consideravelmente do que os demais anos,principalmente de 2005 à 2011. O número de jogos lançados mais alto é mais que 100x o número mínimo de jogos lançados.``

# %%
#VERIFICANDO AS MAIORES VENDAS POR PLATAFORMA
sell_per_platform = df_games.groupby(['platform'])['total_sales'].count().sort_values(ascending=False).reset_index(name='best_sellers')
sell_per_platform.head(10)
# Out:
#   platform  best_sellers
# 0      ps2          2161
# 1       ds          2151
# 2      ps3          1329
# 3      wii          1320
# 4     x360          1262
# 5      psp          1209
# 6       ps          1197
# 7       pc           974
# 8       xb           824
# 9      gba           822

# %%
# CONSTRUINDO UMA DISTRIBUIÇÃO COM BASE EM DADOS PARA CADA ANO. 
sns.lineplot( 
    data=df_games[df_games['platform'].isin(['ps2', 'ds', 'ps3', 'wii', 'x360','psp','ps','pc','xb','gba'])],
    x='year_of_release',
    y='total_sales',  
    hue='platform',
    errorbar=None,
    estimator='sum'  

)
plt.show()

# %%
# CONSTRUINDO UMA DISTRIBUIÇÃO COM BASE EM DADOS PARA CADA ANO. 
sns.lineplot( 
    data=df_games[df_games['platform'].isin(['ps2', 'ds', 'ps3', 'wii', 'x360','psp','ps','pc','xb','gba'])],
    x='year_of_release',
    y='total_sales',  
    hue='platform',

)
plt.show()

# %% [markdown]
# ``De acordo com o gráfico, o tempo que uma plataforma demora para desaparecer e uma nova surgir é em torno de 10 anos.(O gráfico pode conter alguns erros pois nem todos os anos estavam preenchidos no dataframe original.) Plataformas como ps e ps2 foram um sucesso estrondoso de vendas de vendas no no final do século passado e no início do atual. ``

# %%
# FILTRANDO O DATAFRAME E SELECIONANDO APENAS AS 10 PLATAFORMAS COM MAIORES VENDAS A PARTIR DOS ANOS 2000
new_df_games = (df_games[(df_games['platform'].isin(['ps2', 'ds', 'ps3', 'wii', 'x360', 'psp', 'ps', 'pc', 'xb', 'gba'])) & (df_games['year_of_release'] >= 2000)])
new_df_games
# Out:
#                                                    name platform  \
# 0                                            wii sports      wii
# 2                                        mario kart wii      wii
# 3                                     wii sports resort      wii
# 6                                 new super mario bros.       ds
# 7                                              wii play      wii
# ...                                                 ...      ...
# 16708                woody woodpecker in crazy castle 5      gba
# 16709  score international baja 1000: the official game      ps2
# 16710                     samurai warriors: sanada maru      ps3
# 16711                                  lma manager 2007     x360
# 16713                                  spirits & spells      gba
#
#        year_of_release     genre  na_sales  eu_sales  jp_sales  other_sales  \
# 0                 2006    sports     41.36     28.96      3.77         8.45
# ...

# %% [markdown]
# ``Decidi trabalhar apenas com dados de jogos lançados nos anos 2000 em diante. O motivo dessa escolha é por causa do salto tecnologico que a indústria de videogames e consoles deu a partir do começo do século.``

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# <b>Comentário: </b> <a class="tocSkip"></a>
#
# É incomum usar dados de mais de 2-3 anos ao prever as vendas do próximo ano, mesmo no caso de negócios tradicionais. E na indústria dinâmica de jogos de computador, evitar intervalos de tempo mais longos é aconselhável, pois isso certamente levará ao rastreamento de tendências obsoletas. Mas também não se deve usar um período muito curto. O período ideal seria 2014-2016 ou 2015-2016 ou 2013-2016 - ou seja, um período de 2-3 anos.
# </div>

# %%
# VERIFICANDO O SUCESSO DE VENDAS POR PLATAFORMAS A PARTIR DOS ANOS 2000
new_df_games.groupby(['platform'])['total_sales'].count().sort_values(ascending=False).reset_index(name='best_sellers')
# Out:
#   platform  best_sellers
# 0       ds          2151
# 1      ps2          2139
# 2      ps3          1329
# 3      wii          1320
# 4     x360          1262
# 5      psp          1209
# 6       pc           930
# 7       xb           824
# 8      gba           822
# 9       ps           274

# %%
#VERIFICANDO A LIDERANÇA EM VENDAS DE CADA PLATAFORMA A PARTIR DOS ANOS 2000.
sns.lineplot(
    data=new_df_games,
    x='year_of_release',
    y='total_sales',
    hue='platform',
    errorbar=None,
    estimator='sum'

)
plt.show()

# %% [markdown]
# ``As plataformas mais lucrativas são 'ps2','wii','x360' e 'ds'. 'ps2' por exemplo se manteve vendendo mesmo quando seu sucessor 'ps3' ja havia sido lançado. A mesma coisa acontece com 'ds', que se manteve vendendo mesmo após o lançamento do 'wii'. Já 'x360' pode não ter sido tão lucrativa quanto as outras mas se manteve um bom tempo dentro do mercado com um pico de vendas que supera até mesmo o 'ds'. Em geral todas as plataformas não chegaram até 2016 em alta, provavelmente por causa de sucessores que chamaram a atenção do público pelas novas tecnologias envolvidas, assim como sequências de jogos.``

# %%
# CONSTRUINDO UM DIAGRAMA DE CAIXA PARA AS VENDAS GLOBAIS DE TODOS OS JOGOS.
sns.boxplot(data=new_df_games, y='total_sales', hue='platform', fill=False, gap=.1)

plt.show()

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# <b>Comentário: </b> <a class="tocSkip"></a>
#
# Devido à presença de outliers, o boxplot torna-se difícil de visualizar adequadamente. Para melhorar em futuras ocasiões, considere remover os outliers da representação gráfica ou utilizar uma escala logarítmica.
# </div>

# %%
# CONSTRUINDO UM DIAGRAMA DE CAIXA PARA AS VENDAS GLOBAIS DE TODOS OS JOGOS.
sns.boxplot(data=new_df_games, y='total_sales', hue='platform',fill=False, gap=.1)

plt.show()

# %%
# OBTENDO AS VENDAS MÉDIAS DE CADA PLATAFORMA.
mean_sales = new_df_games.groupby('platform')['total_sales'].mean().sort_values(ascending=False).reset_index(name='mean_sales')
mean_sales
# Out:
#   platform  mean_sales
# 0     x360    0.769746
# 1      ps3    0.706667
# 2      wii    0.687508
# 3      ps2    0.582613
# 4       ps    0.513504
# 5      gba    0.386679
# 6       ds    0.374765
# 7       xb    0.312791
# 8      psp    0.243218
# 9       pc    0.224538

# %%
# VERIFICANDO COMO AS AVALIAÇÕES DE USUÁRIOS E PROFISSIONAIS AFETAM AS VENDAS DE UMA PLATAFORMA POPULAR.
condition = new_df_games[new_df_games['platform'] == 'wii']
fig, ax = plt.subplots(1, 2, figsize=(10, 4))
new_df_games[new_df_games['platform'] == 'wii'].plot.scatter(ax=ax[0], x='user_score', y='total_sales', alpha=0.36, xlabel='Nota dos Usuários', ylabel='Total de Vendas', title='User Score x Total Sales')
new_df_games[new_df_games['platform'] == 'wii'].plot.scatter(ax=ax[1], x='critic_score', y='total_sales', alpha=0.36, xlabel='Nota dos Críticos', ylabel='Total de Vendas', title='Critic Score x Total Sales')
plt.show()

user_corr = condition['user_score'].corr(condition['total_sales'])
critic_corr = condition['critic_score'].corr(condition['total_sales'])

print(f"A correlação entre User Score e Total Sales é de: {user_corr}")
print(f"A correlação entre Critic Score e Total Sales é de: {critic_corr}")
# Out:
# A correlação entre User Score e Total Sales é de: 0.11241436067003177
# A correlação entre Critic Score e Total Sales é de: 0.17755988806089953

# %%
# CORRELACIONANDO VENDAS E CRITICA DE OUTRAS PLATAFORMAS. 1/2
condition2 = new_df_games[new_df_games['platform'] == 'x360']
fig, ax = plt.subplots(1, 2, figsize=(10, 4))
new_df_games[new_df_games['platform'] == 'x360'].plot.scatter(ax=ax[0], x='user_score', y='total_sales', alpha=0.36, xlabel='Nota dos Usuários', ylabel='Total de Vendas', title='User Score x Total Sales')
new_df_games[new_df_games['platform'] == 'x360'].plot.scatter(ax=ax[1], x='critic_score', y='total_sales', alpha=0.36, xlabel='Nota dos Críticos', ylabel='Total de Vendas', title='Critic Score x Total Sales')
plt.show()


user_corr2 = condition2['user_score'].corr(condition2['total_sales'])

critic_corr2 = condition2['critic_score'].corr(condition2['total_sales'])


print(f"A correlação entre User Score e Total Sales é de: {user_corr2}")

print(f"A correlação entre Critic Score e Total Sales é de: {critic_corr2}")
# Out:
# A correlação entre User Score e Total Sales é de: 0.1144588297845418
# A correlação entre Critic Score e Total Sales é de: 0.3937358653072587

# %%
# CORRELACIONANDO VENDAS E CRITICA DE OUTRAS PLATAFORMAS. 2/2
condition3 = new_df_games[new_df_games['platform'] == 'ps3']
fig, ax = plt.subplots(1, 2, figsize=(10, 4))
new_df_games[new_df_games['platform'] == 'ps3'].plot.scatter(ax=ax[0], x='user_score', y='total_sales', alpha=0.36, xlabel='Nota dos Usuários', ylabel='Total de Vendas', title='User Score x Total Sales')
new_df_games[new_df_games['platform'] == 'ps3'].plot.scatter(ax=ax[1], x='critic_score', y='total_sales', alpha=0.36, xlabel='Nota dos Críticos', ylabel='Total de Vendas', title='Critic Score x Total Sales')
plt.show()


user_corr3 = condition3['user_score'].corr(condition3['total_sales'])

critic_corr3 = condition3['critic_score'].corr(condition3['total_sales'])


print(f"A correlação entre User Score e Total Sales é de: {user_corr3}")

print(f"A correlação entre Critic Score e Total Sales é de: {critic_corr3}")
# Out:
# A correlação entre User Score e Total Sales é de: 0.12584269665485215
# A correlação entre Critic Score e Total Sales é de: 0.4336947594503306

# %% [markdown]
# ``Ao que tudo indica não há uma correlação forte entre vendas e avaliações de um jogo, tanto pelos usuários quanto pela crítica. Mas ainda assim as avaliações da crítica possuem uma correlação maior com as vendas que as avaliações dadas pelos usuários. ``

# %%
#OBTENDO O NÚMERO DE JOGOS POR GÊNERO
new_df_games.groupby('genre')['name'].count().sort_values(ascending=False).reset_index(name= 'games_by_genre')
# Out:
#            genre  games_by_genre
# 0         action            2383
# 1         sports            1738
# 2           misc            1445
# 3   role-playing            1019
# 4        shooter             998
# 5      adventure             995
# 6         racing             912
# 7     simulation             723
# 8       platform             567
# 9       fighting             533
# 10      strategy             506
# 11        puzzle             441

# %%
#VERIFICANDO OS GÊNEROS MAIS LUCRATIVOS.
sns.boxplot(data=new_df_games, y='total_sales',hue='genre', fill=False, gap=.1)

plt.show()

# %% [markdown]
# ``Em geral todos os gêneros possuem outliers, mas os 6 primeiros gêneros possuem valores mais significativos. Quanto ao restante dos gêneros, apesar de alguns outliers, todos possuem vendas concentradas em valores menores.``

# %%
#VERIFICANDO OS GÊNEROS MAIS LUCRATIVOS.
sns.boxplot(data=new_df_games, y='total_sales',hue='genre', fill=False, gap=.1)

plt.show()

# %% [markdown]
# ### PERFIL DE USUÁRIO

# %%
#CRIANDO UM PERFIL DE USUÁRIO PARA A REGIÃO NORTE AMERICANA.
new_df_games[['na_sales', 'platform','genre']].sort_values(ascending=False,by='na_sales').reset_index().head(5)
# Out:
#    index  na_sales platform     genre
# 0      0     41.36      wii    sports
# 1      2     15.68      wii    racing
# 2      3     15.61      wii    sports
# 3     14     15.00     x360      misc
# 4      8     14.44      wii  platform

# %%
# VERIFICANDO SE AS CLASSIFICAÇÕES ESRB AFETAM AS VENDAS EM REGIÕES INDIVIDUAIS - NA.
new_df_games.groupby(['rating'])['na_sales'].sum().sort_values(ascending=False).reset_index()
# Out:
#     rating  na_sales
# 0        E   1118.54
# 1        T    640.36
# 2        M    632.83
# 3  missing    371.50
# 4     E10+    302.88
# 5       EC      1.44
# 6       AO      1.26
# 7       RP      0.00

# %%
# CRIANDO UM PERFIL DE USUÁRIO PARA A REGIÃO EUROPÉIA.
new_df_games[['eu_sales', 'platform', 'genre']].sort_values(ascending=False, by='eu_sales').reset_index().head(5)
# Out:
#    index  eu_sales platform       genre
# 0      0     28.96      wii      sports
# 1      2     12.76      wii      racing
# 2     10     10.95       ds  simulation
# 3      3     10.93      wii      sports
# 4     19      9.20       ds        misc

# %%
# VERIFICANDO SE AS CLASSIFICAÇÕES ESRB AFETAM AS VENDAS EM REGIÕES INDIVIDUAIS - EU.
new_df_games.groupby(['rating'])['eu_sales'].sum().sort_values(ascending=False).reset_index()
# Out:
#     rating  eu_sales
# 0        E    602.49
# 1        M    387.76
# 2        T    353.41
# 3  missing    261.69
# 4     E10+    155.21
# 5       AO      0.61
# 6       EC      0.09
# 7       RP      0.04

# %%
# CRIANDO UM PERFIL DE USUÁRIO PARA A REGIÃO JAPONESA.
new_df_games[['jp_sales', 'platform', 'genre']].sort_values(ascending=False, by='jp_sales').reset_index().head(5)
# Out:
#    index  jp_sales platform         genre
# 0      6      6.50       ds      platform
# 1     20      6.04       ds  role-playing
# 2     27      5.65       ds  role-playing
# 3     25      5.38      gba  role-playing
# 4     43      5.33       ds    simulation

# %%
# VERIFICANDO SE AS CLASSIFICAÇÕES ESRB AFETAM AS VENDAS EM REGIÕES INDIVIDUAIS - JP.
new_df_games.groupby(['rating'])['jp_sales'].sum().sort_values(ascending=False).reset_index()
# Out:
#     rating  jp_sales
# 0  missing    282.31
# 1        E    148.49
# 2        T    109.63
# 3        M     48.88
# 4     E10+     31.62
# 5       AO      0.00
# 6       EC      0.00
# 7       RP      0.00

# %% [markdown]
# ``Segundo os dados, a empresa Nintendo tem uma excelente reputação no mercado mundial  de videogames, onde em 3 diferentes regiões teve seus consoles 'ds' e 'wii' aparecendo no top 5 quando o assunto é jogo mais vendido para determinada plataforma. Os gêneros mais vendidos parecem ser semelhantes tanto na região norte americana quanto na região européia. Já na região japonesa os gêneros de sucesso se diferem das outras regiões. Quanto ao impacto da classificação ESRB nas vendas de cada região, todas as maiores vendas giram em torno das classificações E, T e M, o que mostra que o público jovem de crianças à jovens adultos possuem uma biblioteca de jogos bem diversificada para sua respectiva faixa etária.``

# %% [markdown]
# ### TESTANDO HIPÓTESES

# %%
xone_score = df_games[df_games['platform'] == 'xone']['user_score'].dropna()
pc_score = df_games[df_games['platform'] == 'pc']['user_score'].dropna()

xone_score.var(), pc_score.var()
# Out:
# (1.9069968429360695, 2.3407871413372066)

# %%
# Teste as hipóteses
# Hipotese nula - as classificações médias dos usuarios das plataformas xbox one e pc são as mesmas.
# Hipotese alternativa - as classificações médias dos usuarios das plataformas xbox one e pc são diferentes
alpha = 0.05

results = st.ttest_ind(xone_score, pc_score, equal_var=False)

print('valor-p:', results.pvalue)

if results.pvalue < alpha:
    print("Rejeitamos a hipótese nula. As médias dos usuários das duas plataformas são significativamente diferentes.")
else:
    print("Não rejeitamos a hipótese nula. Não há diferença significativa entre as médias dos usuários das duas plataformas.")
# Out:
# valor-p: 4.935072360183574e-06
# Rejeitamos a hipótese nula. As médias dos usuários das duas plataformas são significativamente diferentes.

# %% [markdown]
# ``Nesse teste de hipótese, podemos verificar que a classificação média dos usuários para duas diferentes plataformas são diferentes. Isso significa que não podemos afirmar nada para x plataforma tomando como base os dados de outra plataforma completamente diferente. Provavelmente a imersão, gráficos e desempenho dos jogos é diferente nas duas plataformas, e por isso a classificação dos usuários também é diferente.``

# %%
action_score = df_games[df_games['genre'] == 'action']['user_score'].dropna()
sports_score = df_games[df_games['genre'] == 'sports']['user_score'].dropna()

action_score.var(), sports_score.var()
# Out:
# (2.031746898033205, 2.596932049893596)

# %%
# Teste as hipóteses
# Hipotese nula - as classificações médias dos usuarios dos gêneros action e sports são as mesmas.
# Hipotese alternativa - as classificações médias dos usuarios dos gêneros action e sports são diferentes
alpha = 0.05

results = st.ttest_ind(action_score, sports_score, equal_var=False)

print('valor-p:', results.pvalue)

if results.pvalue < alpha:
    print("Rejeitamos a hipótese nula. As médias dos usuários para os dois gêneros são significativamente diferentes.")
else:
    print("Não rejeitamos a hipótese nula. Não há diferença significativa entre as médias dos dois gêneros.")
# Out:
# valor-p: 0.12024530426190533
# Não rejeitamos a hipótese nula. Não há diferença significativa entre as médias dos dois gêneros.

# %% [markdown]
# ``Nesse teste de hipótese, não podemos rejeitar a hipótese nula. Podemos verificar que as classificações médias dos usuários para os dois gêneros não possuem uma diferença significativa, e com isso podemos levantar a hipótese de que os dois gêneros possuem tantos jogadores fiéis à sua jogabilidade individual, que a média de seus usuários se torna ligeiramente similar.``

# %% [markdown]
# `` - Para formular as hipóteses nulas e alternativas, tomo como base que a nula é a hipótese que eu quero testar, enquanto a alternativa é a contra resposta caso a nula seja rejeitada.``

# %% [markdown]
# <div class="alert alert-block alert-danger">
#
# <b>Comentário v2: </b> <a class="tocSkip"></a>
#
# Entendi! A estrutura do teste de hipótese está correta, mas precisamos remover os dados nulos das variáveis _xone_score, pc_score, sports_score e action_score_ para obter um resultado válido (e não o `nan`). Atualize o código para garantir que esses valores nulos sejam removidos antes de prosseguir com o teste.
#
#     Exemplo:
#
#     xbox_one_scores = df[df['platform'] == 'XOne']['user_score'].dropna()
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# <b>Comentário: </b> <a class="tocSkip"></a>
#
# Apesar dos comentários no código, seria ideal adicionar uma conclusão final com os achados do estudo.
# <div>
